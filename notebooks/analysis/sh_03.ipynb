# %%
import os
import pandas as pd
import numpy as np
import pyarrow.parquet as pq
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# Setup directory paths (using current working directory for Jupyter)
notebook_dir = os.getcwd()
root_dir=os.path.dirname(os.path.dirname(notebook_dir))

output_dir = os.path.join(root_dir, "output", "sh-03")
file_path = os.path.join(root_dir, "data", "SH-03 COBBLE 11122024.parquet")

print(f"Target file path: {file_path}")
print(f"Output directory: {output_dir}")
# Out:
# Target file path: c:\Users\Aditya Singh\Desktop\INTERN\data\SH-03 COBBLE 11122024.parquet
# Output directory: c:\Users\Aditya Singh\Desktop\INTERN\output\sh-03

# %%
print(f"Reading and downsampling data from {file_path}")
print("Processing in chunks with vectorized downsampling...")

parquet_file = pq.ParquetFile(file_path)
downsampled_chunks = []
global_row_count = 0

# Process in batches of 10,000 rows
for batch in parquet_file.iter_batches(batch_size=10000):
    df_chunk = batch.to_pandas()
    chunk_len = len(df_chunk)
    
    # Calculate the exact starting index for this chunk to maintain the global "every 100th row" rule
    remainder = global_row_count % 100
    start_idx = 0 if remainder == 0 else (100 - remainder)
    
    if start_idx < chunk_len:
        # Slicing with [start::100] is fully vectorized and incredibly fast
        downsampled_chunks.append(df_chunk.iloc[start_idx::100].copy())
        
    global_row_count += chunk_len
    print(f"Processed {global_row_count} rows...", end='\r')
    
print(f"\nFinished reading. Concatenating chunks...")
df_down = pd.concat(downsampled_chunks, ignore_index=True)
print(f"Downsampled dataframe shape: {df_down.shape}")

# Ensure Timestamp is handled correctly
if 'Timestamp' in df_down.columns:
    df_down['Timestamp'] = pd.to_datetime(df_down['Timestamp'])
    print("Timestamp column successfully converted to datetime.")
# Out:
# Reading and downsampling data from c:\Users\Aditya Singh\Desktop\INTERN\data\SH-03 COBBLE 11122024.parquet
# Processing in chunks with vectorized downsampling...
# Processed 1260000 rows...
# Finished reading. Concatenating chunks...
# Downsampled dataframe shape: (12600, 10646)
# Timestamp column successfully converted to datetime.

# %%
print("Pre-calculating standard deviations for all columns...")
# Convert bools to float for unified std calculation; non-numeric columns will be ignored here
numeric_bool_df = df_down.select_dtypes(include=[np.number, 'bool'])
stds = numeric_bool_df.astype(float).std().fillna(0)
print("Standard deviations calculated successfully.")
# Out:
# Pre-calculating standard deviations for all columns...
# Standard deviations calculated successfully.

# %%
print("Identifying column types (Boolean, Constant, Analog)...")
constant_cols = []
bool_cols = []
analog_cols = []

# Process numeric/boolean columns based on pre-calculated stds
for col in df_down.columns:
    if col in stds.index:
        col_std = stds[col]
        if col_std == 0:
            constant_cols.append(col)
        elif pd.api.types.is_bool_dtype(df_down[col]):
            bool_cols.append(col)
        else:
            # Fast check for 0/1 columns using downsampled data
            unique_vals = set(df_down[col].dropna().unique())
            if unique_vals.issubset({0, 1, 0.0, 1.0}):
                bool_cols.append(col)
            else:
                analog_cols.append(col)
    else:
        # Handle non-numeric columns (e.g., strings/objects)
        if df_down[col].nunique(dropna=False) <= 1:
            constant_cols.append(col)
        else:
            analog_cols.append(col)

print(f"Found {len(bool_cols)} boolean, {len(constant_cols)} constant, and {len(analog_cols)} analog columns.")
# Out:
# Identifying column types (Boolean, Constant, Analog)...
# Found 1723 boolean, 7457 constant, and 1466 analog columns.

# %%
def sort_cols_by_std(cols):
    col_stds = {c: stds[c] if c in stds.index else 0 for c in cols}
    return sorted(col_stds, key=col_stds.get, reverse=True)

print("Sorting columns by standard deviation (high fluctuation to low)...")
sorted_bool = sort_cols_by_std(bool_cols)
sorted_analog = sort_cols_by_std(analog_cols)
sorted_const = sort_cols_by_std(constant_cols)

print("Saving categorized datasets to CSV...")
# Updated saving paths to output_dir
df_down[sorted_bool].to_csv(os.path.join(output_dir, "boolean_columns.csv"), index=False)
df_down[sorted_analog].to_csv(os.path.join(output_dir, "analog_columns.csv"), index=False)
df_down[sorted_const].to_csv(os.path.join(output_dir, "constant_columns.csv"), index=False)
print(f"Categorized CSVs saved successfully to {output_dir}")
# Out:
# Sorting columns by standard deviation (high fluctuation to low)...
# Saving categorized datasets to CSV...
# Categorized CSVs saved successfully to c:\Users\Aditya Singh\Desktop\INTERN\output\sh-03

# %%
print("Extracting specific parameters (Speed, Torque, Current, Power, Looper, Vibration)...")
param_keywords = {
    'speed': ['speed'],
    'torque': ['torque'],
    'current': ['current'],
    'power': ['power'],
    'looper': ['loop', 'l1112', 'l1213', 'l1314', 'l1415', 'l1516', 'l1617', 'l1718', 'l1819', 'l1920', 'l2021', 'l24fb'],
    'vibration': ['vib'] # Updated keyword from 'vibr' to 'vib'
}

params_cols = {k: [] for k in param_keywords.keys()}
all_cols_lower = {str(col).lower(): col for col in df_down.columns}

# Vector-like matching using dictionary lookups
for col_lower, original_col in all_cols_lower.items():
    for param, keywords in param_keywords.items():
        if any(kw in col_lower for kw in keywords):
            params_cols[param].append(original_col)

all_param_cols = list(set().union(*params_cols.values()))

# Add Timestamp to the front of all_parameters if it exists
if 'Timestamp' in df_down.columns and 'Timestamp' not in all_param_cols:
    all_param_cols.insert(0, 'Timestamp')

print(f"Found {len(all_param_cols)} columns across all specified parameters.")
df_down[all_param_cols].to_csv(os.path.join(output_dir, "all_parameters.csv"), index=False)
# Out:
# Extracting specific parameters (Speed, Torque, Current, Power, Looper, Vibration)...
# Found 967 columns across all specified parameters.

# %%
print("Finding highest standard deviation column for each parameter...")
highest_cols = []
for param, cols in params_cols.items():
    if not cols:
        print(f"  {param}: No columns found.")
        continue
    
    param_stds = {c: stds[c] if c in stds.index else 0 for c in cols}
    highest_col = max(param_stds, key=param_stds.get)
    highest_val = param_stds[highest_col]
    
    print(f"  {param}: {highest_col} (std = {highest_val:.4f})")
    highest_cols.append(highest_col)

# Ensure Timestamp accompanies highest columns output
output_cols = list(highest_cols)
if 'Timestamp' in df_down.columns:
    output_cols.insert(0, 'Timestamp')

print("\nSaving highest fluctuation dataset...")
df_down[output_cols].to_csv(os.path.join(output_dir, "highest_std_parameters.csv"), index=False)
# Out:
# Finding highest standard deviation column for each parameter...
#   speed: [14:23]Drive Fbk Speed PR002 (std = 6409.2874)
#   torque: [19:57]PR003: Drive - Reference Torque Positive (std = 940.8041)
#   current: [19:37]SH003: Drive - Actual Current (std = 1340.7218)
#   power: [7:19]CZ75 COA Fan 01 Drv Power Count Val (std = 853.4106)
#   looper: [17:24]Loop Height ANALOGUE L1415 (std = 5027.4731)
#   vibration: [12:108]CZ75_SNS_VT75_11_CA_FAN1_VIB (std = 620.4932)
#
# Saving highest fluctuation dataset...

# %%
def normalize_series(series):
    """Scales a pandas Series strictly between 0 and 1."""
    min_val = series.min()
    max_val = series.max()
    if max_val == min_val:
        return series * 0.0  # Avoid division by zero if the column is constant
    return (series - min_val) / (max_val - min_val)

# %%
param = 'speed'
if params_cols[param] and 'Timestamp' in df_down.columns:
    # Change this pattern in ALL your plot cells:
    param_stds = {c: stds[c] for c in params_cols[param] if c in stds.index}
    col = max(param_stds, key=param_stds.get)

    plt.figure(figsize=(15, 4))
    plt.plot(df_down['Timestamp'], normalize_series(df_down[col]), linewidth=1, color='steelblue')
    plt.title(f"Speed: {col}", fontsize=14, fontweight='bold')
    plt.ylabel("Normalized Value (0 to 1)", fontsize=11)
    plt.xlabel("Timestamp", fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.ylim(-0.05, 1.05)
    plt.gca().xaxis.set_major_locator(mdates.MinuteLocator(interval=10))
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
    plt.savefig(os.path.join(output_dir, f"{param}_normalized_plot.png"), dpi=150, bbox_inches='tight')
    plt.show()
else:
    print(f"No data found for {param}")

# %%
param = 'torque'
if params_cols[param] and 'Timestamp' in df_down.columns:
    # Change this pattern in ALL your plot cells:
    param_stds = {c: stds[c] for c in params_cols[param] if c in stds.index}
    col = max(param_stds, key=param_stds.get)
    
    plt.figure(figsize=(15, 4))
    plt.plot(df_down['Timestamp'], normalize_series(df_down[col]), linewidth=1, color='darkorange')
    plt.title(f"Torque: {col}", fontsize=14, fontweight='bold')
    plt.ylabel("Normalized Value (0 to 1)", fontsize=11)
    plt.xlabel("Timestamp", fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.ylim(-0.05, 1.05)
    plt.gca().xaxis.set_major_locator(mdates.MinuteLocator(interval=10))
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
    plt.savefig(os.path.join(output_dir, f"{param}_normalized_plot.png"), dpi=150, bbox_inches='tight')
    plt.show()
else:
    print(f"No data found for {param}")

# %%
param = 'current'
if params_cols[param] and 'Timestamp' in df_down.columns:
    # Change this pattern in ALL your plot cells:
    param_stds = {c: stds[c] for c in params_cols[param] if c in stds.index}
    col = max(param_stds, key=param_stds.get)
    
    plt.figure(figsize=(15, 4))
    plt.plot(df_down['Timestamp'], normalize_series(df_down[col]), linewidth=1, color='forestgreen')
    plt.title(f"Current: {col}", fontsize=14, fontweight='bold')
    plt.ylabel("Normalized Value (0 to 1)", fontsize=11)
    plt.xlabel("Timestamp", fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.ylim(-0.05, 1.05)
    plt.gca().xaxis.set_major_locator(mdates.MinuteLocator(interval=10))
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
    plt.savefig(os.path.join(output_dir, f"{param}_normalized_plot.png"), dpi=150, bbox_inches='tight')
    plt.show()
else:
    print(f"No data found for {param}")

# %%
param = 'power'
if params_cols[param] and 'Timestamp' in df_down.columns:
    # Change this pattern in ALL your plot cells:
    param_stds = {c: stds[c] for c in params_cols[param] if c in stds.index}
    col = max(param_stds, key=param_stds.get)

    
    norm_series = normalize_series(df_down[col])
    smoothed_series = norm_series.rolling(window=30, min_periods=1, center=True).mean()
    
    plt.figure(figsize=(15, 4))
    plt.plot(df_down['Timestamp'], smoothed_series, linewidth=1, color='crimson')
    plt.title(f"Power: {col}", fontsize=14, fontweight='bold')
    plt.ylabel("Normalized Value (0 to 1)", fontsize=11)
    plt.xlabel("Timestamp", fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.ylim(-0.05, 1.05)
    plt.gca().xaxis.set_major_locator(mdates.MinuteLocator(interval=10))
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
    plt.savefig(os.path.join(output_dir, f"{param}_normalized_plot.png"), dpi=150, bbox_inches='tight')
    plt.show()
else:
    print(f"No data found for {param}")

# %%
param = 'looper'
if params_cols[param] and 'Timestamp' in df_down.columns:
    # Change this pattern in ALL your plot cells:
    param_stds = {c: stds[c] for c in params_cols[param] if c in stds.index}
    col = max(param_stds, key=param_stds.get)
    
    plt.figure(figsize=(15, 4))
    plt.plot(df_down['Timestamp'], normalize_series(df_down[col]), linewidth=1, color='purple')
    plt.title(f"Looper: {col}", fontsize=14, fontweight='bold')
    plt.ylabel("Normalized Value (0 to 1)", fontsize=11)
    plt.xlabel("Timestamp", fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.ylim(-0.05, 1.05)
    plt.gca().xaxis.set_major_locator(mdates.MinuteLocator(interval=10))
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
    plt.savefig(os.path.join(output_dir, f"{param}_normalized_plot.png"), dpi=150, bbox_inches='tight')
    plt.show()
else:
    print(f"No data found for {param}")

# %%
param = 'vibration'
if params_cols[param] and 'Timestamp' in df_down.columns:
    # Change this pattern in ALL your plot cells:
    param_stds = {c: stds[c] for c in params_cols[param] if c in stds.index}
    col = max(param_stds, key=param_stds.get)
    
    # 1. Normalize original series
    norm_series = normalize_series(df_down[col])
    
    # 2. Linearize/smooth trends over a 30-second rolling window
    smoothed_series = norm_series.rolling(window=30, min_periods=1, center=True).mean()
    
    plt.figure(figsize=(15, 4))
    plt.plot(df_down['Timestamp'], smoothed_series, linewidth=1.5, color='teal', label='30s Rolling Mean Trend')
    plt.title(f"Vibration (30s Linearized): {col}", fontsize=14, fontweight='bold')
    plt.ylabel("Normalized Value (0 to 1)", fontsize=11)
    plt.xlabel("Timestamp", fontsize=11)
    plt.grid(True, alpha=0.3)
    plt.ylim(-0.05, 1.05)
    plt.gca().xaxis.set_major_locator(mdates.MinuteLocator(interval=10))
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
    plt.savefig(os.path.join(output_dir, f"{param}_normalized_trend_plot.png"), dpi=150, bbox_inches='tight')
    plt.legend()
    plt.show()
else:
    print(f"No data found for {param}")

# %%
param = 'speed'
print(f"=== Top 20 Highest Variance Columns for: {param.upper()} ===")
param_stds = {c: stds[c] for c in params_cols[param] if c in stds.index}
sorted_params = sorted(param_stds.items(), key=lambda x: x[1], reverse=True)[:20]

for idx, (col_name, val) in enumerate(sorted_params, 1):
    print(f"{idx:02d}. Std Dev: {val:.4f} -> {col_name}")
# Out:
# === Top 20 Highest Variance Columns for: SPEED ===
# 01. Std Dev: 6409.2874 -> [14:23]Drive Fbk Speed PR002
# 02. Std Dev: 5900.2518 -> [14:215]Drive Speed Reference PR002
# 03. Std Dev: 5433.2510 -> [14:22]Drive Fbk Speed PR001
# 04. Std Dev: 5000.2927 -> [14:214]Drive Speed Reference PR001
# 05. Std Dev: 4677.9130 -> [14:24]Drive Fbk Speed INSRT_S1
# 06. Std Dev: 4677.9130 -> [14:25]Drive Fbk Speed INSRT_S2
# 07. Std Dev: 4306.3202 -> [14:217]Drive Speed Reference INSRT_S2
# 08. Std Dev: 4245.9862 -> [14:216]Drive Speed Reference INSRT_S1
# 09. Std Dev: 3688.9713 -> [14:21]Drive Fbk Speed EXFRT_S2
# 10. Std Dev: 3499.4705 -> [14:213]Drive Speed Reference EXFRT_S2
# 11. Std Dev: 3223.4976 -> [14:212]Drive Speed Reference EXFRT_S1
# 12. Std Dev: 3221.2554 -> [14:20]Drive Fbk Speed EXFRT_S1
# 13. Std Dev: 3066.4630 -> [6:32]FERT_SEC1_DRV_IDB_DIN_SPEED
# 14. Std Dev: 3044.8273 -> [19:56]PR003: Drive - Reference Speed
# 15. Std Dev: 3025.6148 -> [19:32]PR003: Drive - Actual Speed
# 16. Std Dev: 2787.7469 -> [19:59]SH003: Drive - Reference Speed
# 17. Std Dev: 2787.1810 -> [19:36]SH003: Drive - Actual Speed
# 18. Std Dev: 1925.1538 -> [6:38]S120_1A21PN002_IDB_FUR_CHRG_RT_DIN_SPEED
# 19. Std Dev: 1294.1213 -> [6:64]S120_1A21PN005_IDB_KICK_IN_ARM_03_DIN_SPEED
# 20. Std Dev: 1292.7223 -> [6:56]S120_1A21PN004_IDB_KICK_IN_ARM_02_DIN_SPEED

# %%
param = 'torque'
print(f"=== Top 20 Highest Variance Columns for: {param.upper()} ===")
param_stds = {c: stds[c] for c in params_cols[param] if c in stds.index}
sorted_params = sorted(param_stds.items(), key=lambda x: x[1], reverse=True)[:20]

for idx, (col_name, val) in enumerate(sorted_params, 1):
    print(f"{idx:02d}. Std Dev: {val:.4f} -> {col_name}")
# Out:
# === Top 20 Highest Variance Columns for: TORQUE ===
# 01. Std Dev: 940.8041 -> [19:57]PR003: Drive - Reference Torque Positive
# 02. Std Dev: 940.8041 -> [19:58]PR003: Drive - Reference Torque Negative
# 03. Std Dev: 665.3954 -> [6:58]S120_1A21PN004_IDB_KICK_IN_ARM_02_DIN_TORQUE
# 04. Std Dev: 584.5848 -> [6:40]S120_1A21PN002_IDB_FUR_CHRG_RT_DIN_TORQUE
# 05. Std Dev: 540.8615 -> [6:72]S120_1A21PN006_IDB_KICK_IN_ARM_04_DIN_TORQUE
# 06. Std Dev: 450.2207 -> [6:52]S120_1A21PN003_IDB_KICK_IN_ARM_01_DIN_TORQUE
# 07. Std Dev: 430.9883 -> [6:66]S120_1A21PN005_IDB_KICK_IN_ARM_03_DIN_TORQUE
# 08. Std Dev: 430.8613 -> [6:34]FERT_SEC1_DRV_IDB_DIN_TORQUE
# 09. Std Dev: 327.2815 -> [6:46]S120_1A21PN011_IDB_FUR_DHG_RT_DIN_TORQUE
# 10. Std Dev: 150.0991 -> [19:38]SH003: Drive - Actual Torque
# 11. Std Dev: 19.8476 -> [13:12]STD13 - T FBK Torque Norm
# 12. Std Dev: 19.1850 -> [13:5]STD06 - T FBK Torque Norm
# 13. Std Dev: 19.1825 -> [13:9]STD10 - T FBK Torque Norm
# 14. Std Dev: 18.9659 -> [13:11]STD12 - T FBK Torque Norm
# 15. Std Dev: 18.7241 -> [13:13]STD14 - T FBK Torque Norm
# 16. Std Dev: 18.6842 -> [13:8]STD09 - T FBK Torque Norm
# 17. Std Dev: 18.4845 -> [13:10]STD11 - T FBK Torque Norm
# 18. Std Dev: 17.8037 -> [13:14]STD15 - T FBK Torque Norm
# 19. Std Dev: 17.4198 -> [13:15]STD16 - T FBK Torque Norm
# 20. Std Dev: 17.3686 -> [13:6]STD07 - T FBK Torque Norm

# %%
param = 'current'
print(f"=== Top 20 Highest Variance Columns for: {param.upper()} ===")
param_stds = {c: stds[c] for c in params_cols[param] if c in stds.index}
sorted_params = sorted(param_stds.items(), key=lambda x: x[1], reverse=True)[:20]

for idx, (col_name, val) in enumerate(sorted_params, 1):
    print(f"{idx:02d}. Std Dev: {val:.4f} -> {col_name}")
# Out:
# === Top 20 Highest Variance Columns for: CURRENT ===
# 01. Std Dev: 1340.7218 -> [19:37]SH003: Drive - Actual Current
# 02. Std Dev: 1200.8500 -> [6:39]S120_1A21PN002_IDB_FUR_CHRG_RT_DIN_CURRENT
# 03. Std Dev: 1156.2723 -> [6:65]S120_1A21PN005_IDB_KICK_IN_ARM_03_DIN_CURRENT
# 04. Std Dev: 1123.7673 -> [6:33]FERT_SEC1_DRV_IDB_DIN_CURRENT
# 05. Std Dev: 1117.3880 -> [6:51]S120_1A21PN003_IDB_KICK_IN_ARM_01_DIN_CURRENT
# 06. Std Dev: 1076.0113 -> [6:71]S120_1A21PN006_IDB_KICK_IN_ARM_04_DIN_CURRENT
# 07. Std Dev: 1075.5340 -> [6:57]S120_1A21PN004_IDB_KICK_IN_ARM_02_DIN_CURRENT
# 08. Std Dev: 821.6605 -> [6:97]S120_1A21PN010_IDB_KICK_OFF_4_DIN_CURRENT
# 09. Std Dev: 539.7677 -> [6:45]S120_1A21PN011_IDB_FUR_DHG_RT_DIN_CURRENT
# 10. Std Dev: 314.8727 -> [7:17]CZ75 COA Fan 01 Drv Current Count Val
# 11. Std Dev: 220.5339 -> [2:297]PLC01_HMI_STATUS_DCBUS_STATUS_SLM1_LINEUP2_LINE_CURRENT
# 12. Std Dev: 218.5275 -> [2:301]PLC01_HMI_STATUS_DCBUS_STATUS_SLM3_LINEUP2_LINE_CURRENT
# 13. Std Dev: 161.6337 -> [2:305]PLC01_HMI_STATUS_DCBUS_STATUS_SLM1_LINEUP3_LINE_CURRENT
# 14. Std Dev: 157.8269 -> [2:309]PLC01_HMI_STATUS_DCBUS_STATUS_SLM3_LINEUP3_LINE_CURRENT
# 15. Std Dev: 140.8353 -> [2:240]PLC01_HMI_STATUS_ENERGY_METER_EM_1A01PN005_CURRENT_L1
# 16. Std Dev: 139.6778 -> [2:242]PLC01_HMI_STATUS_ENERGY_METER_EM_1A01PN005_CURRENT_L3
# 17. Std Dev: 138.7090 -> [2:241]PLC01_HMI_STATUS_ENERGY_METER_EM_1A01PN005_CURRENT_L2
# 18. Std Dev: 138.3043 -> [2:252]PLC01_HMI_STATUS_ENERGY_METER_EM_1A01PN006_CURRENT_L3
# 19. Std Dev: 134.9447 -> [2:293]PLC01_HMI_STATUS_DCBUS_STATUS_SLM3_LINEUP1_LINE_CURRENT
# 20. Std Dev: 134.7802 -> [2:289]PLC01_HMI_STATUS_DCBUS_STATUS_SLM1_LINEUP1_LINE_CURRENT

# %%
param = 'power'
print(f"=== Top 20 Highest Variance Columns for: {param.upper()} ===")
param_stds = {c: stds[c] for c in params_cols[param] if c in stds.index}
sorted_params = sorted(param_stds.items(), key=lambda x: x[1], reverse=True)[:20]

for idx, (col_name, val) in enumerate(sorted_params, 1):
    print(f"{idx:02d}. Std Dev: {val:.4f} -> {col_name}")
# Out:
# === Top 20 Highest Variance Columns for: POWER ===
# 01. Std Dev: 853.4106 -> [7:19]CZ75 COA Fan 01 Drv Power Count Val
# 02. Std Dev: 341.4968 -> [6:59]S120_1A21PN004_IDB_KICK_IN_ARM_02_DIN_POWER
# 03. Std Dev: 331.8545 -> [6:35]FERT_SEC1_DRV_IDB_DIN_POWER
# 04. Std Dev: 312.2954 -> [2:296]PLC01_HMI_STATUS_DCBUS_STATUS_SLM1_LINEUP2_POWER
# 05. Std Dev: 311.9500 -> [6:41]S120_1A21PN002_IDB_FUR_CHRG_RT_DIN_POWER
# 06. Std Dev: 303.3318 -> [2:300]PLC01_HMI_STATUS_DCBUS_STATUS_SLM3_LINEUP2_POWER
# 07. Std Dev: 279.1349 -> [6:73]S120_1A21PN006_IDB_KICK_IN_ARM_04_DIN_POWER
# 08. Std Dev: 256.7084 -> [2:304]PLC01_HMI_STATUS_DCBUS_STATUS_SLM1_LINEUP3_POWER
# 09. Std Dev: 239.4136 -> [2:308]PLC01_HMI_STATUS_DCBUS_STATUS_SLM3_LINEUP3_POWER
# 10. Std Dev: 233.2697 -> [6:53]S120_1A21PN003_IDB_KICK_IN_ARM_01_DIN_POWER
# 11. Std Dev: 231.6058 -> [2:288]PLC01_HMI_STATUS_DCBUS_STATUS_SLM1_LINEUP1_POWER
# 12. Std Dev: 228.0054 -> [6:67]S120_1A21PN005_IDB_KICK_IN_ARM_03_DIN_POWER
# 13. Std Dev: 221.5811 -> [2:292]PLC01_HMI_STATUS_DCBUS_STATUS_SLM3_LINEUP1_POWER
# 14. Std Dev: 201.4666 -> [19:35]PR003: Drive - Actual Power
# 15. Std Dev: 186.4340 -> [6:47]S120_1A21PN011_IDB_FUR_DHG_RT_DIN_POWER
# 16. Std Dev: 169.1304 -> [2:246]PLC01_HMI_STATUS_ENERGY_METER_EM_1A01PN005_APPARENT_POWER
# 17. Std Dev: 115.2285 -> [6:79]S120_1A21PN007_IDB_KICK_OFF_1_DIN_POWER
# 18. Std Dev: 109.9547 -> [6:85]S120_1A21PN008_IDB_KICK_OFF_2_DIN_POWER
# 19. Std Dev: 101.1112 -> [6:91]S120_1A21PN009_IDB_KICK_OFF_3_DIN_POWER
# 20. Std Dev: 100.0588 -> [6:99]S120_1A21PN010_IDB_KICK_OFF_4_DIN_POWER

# %%
param = 'looper'
print(f"=== Top 20 Highest Variance Columns for: {param.upper()} ===")
param_stds = {c: stds[c] for c in params_cols[param] if c in stds.index}
sorted_params = sorted(param_stds.items(), key=lambda x: x[1], reverse=True)[:20]

for idx, (col_name, val) in enumerate(sorted_params, 1):
    print(f"{idx:02d}. Std Dev: {val:.4f} -> {col_name}")
# Out:
# === Top 20 Highest Variance Columns for: LOOPER ===
# 01. Std Dev: 5027.4731 -> [17:24]Loop Height ANALOGUE L1415
# 02. Std Dev: 4819.2797 -> [17:21]Loop Height ANALOGUE L1112
# 03. Std Dev: 4618.4192 -> [17:23]Loop Height ANALOGUE L1314
# 04. Std Dev: 4617.4456 -> [17:26]Loop Height ANALOGUE L1617
# 05. Std Dev: 4552.8522 -> [17:22]Loop Height ANALOGUE L1213
# 06. Std Dev: 4439.8538 -> [17:25]Loop Height ANALOGUE L1516
# 07. Std Dev: 3160.0778 -> [17:27]Loop Height ANALOGUE L1718
# 08. Std Dev: 2472.4503 -> [17:29]Loop Height ANALOGUE L1920
# 09. Std Dev: 2396.5454 -> [17:28]Loop Height ANALOGUE L1819
# 10. Std Dev: 79.6402 -> [13:20]L1112 - Actual Height
# 11. Std Dev: 78.6373 -> [13:21]L1213 - Actual Height
# 12. Std Dev: 78.5006 -> [13:22]L1314 - Actual Height
# 13. Std Dev: 77.7562 -> [13:23]L1415 - Actual Height
# 14. Std Dev: 67.6206 -> [13:24]L1516 - Actual Height
# 15. Std Dev: 51.3670 -> [13:25]L1617 - Actual Height
# 16. Std Dev: 49.6150 -> [13:26]L1718 - Actual Height
# 17. Std Dev: 40.7657 -> [13:27]L1819 - Actual Height
# 18. Std Dev: 39.2321 -> [13:28]L1920 - Actual Height
# 19. Std Dev: 25.4415 -> [17:31]Loop Height ANALOGUE L24FB
# 20. Std Dev: 12.6563 -> [15:33]Loop Height Fbk: STD11

# %%
param = 'vibration'
print(f"=== Top 20 Highest Variance Columns for: {param.upper()} ===")
param_stds = {c: stds[c] for c in params_cols[param] if c in stds.index}
sorted_params = sorted(param_stds.items(), key=lambda x: x[1], reverse=True)[:20]

for idx, (col_name, val) in enumerate(sorted_params, 1):
    print(f"{idx:02d}. Std Dev: {val:.4f} -> {col_name}")
# Out:
# === Top 20 Highest Variance Columns for: VIBRATION ===
# 01. Std Dev: 620.4932 -> [12:108]CZ75_SNS_VT75_11_CA_FAN1_VIB
# 02. Std Dev: 61.8663 -> [12:112]CZ75_SNS_VT75_21_CA_FAN2_VIB
# 03. Std Dev: 0.4487 -> [9:57]CZ75 COA M75_01 Vib Sns Val
# 04. Std Dev: 0.0448 -> [9:69]CZ75 COA M75_02 Vib Sns Val
# 05. Std Dev: 0.0000 -> [7_250]CZ75 COA Fan 01 Vib Trns VT75_11 fail
# 06. Std Dev: 0.0000 -> [7_251]CZ75 COA Fan 01 Vib Trns VT75_11 High vib wrn
# 07. Std Dev: 0.0000 -> [7_252]CZ75 COA Fan 01 Vib Trns VT75_11 High vib flt
# 08. Std Dev: 0.0000 -> [7_282]CZ75 COA Fan 02 Vib Trns VT75_21 fail
# 09. Std Dev: 0.0000 -> [7_283]CZ75 COA Fan 02 Vib Trns VT75_21 High vib wrn
# 10. Std Dev: 0.0000 -> [7_284]CZ75 COA Fan 02 Vib Trns VT75_21 High vib flt
